# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_market_decrease_fair_df = pd.read_csv("../Resources/City-Pair_Markets_With_A_Substantial_Decrease_In_Average_Fare.csv")

# Display sample data
city_market_decrease_fair_df.head()
# Out:
#        tbl  Year  quarter  citymarketid_1  citymarketid_2       city1  \
# 0  Table 4  2017        2           30423           33198  Austin, TX
# 1  Table 4  2018        3           30325           33044  Denver, CO
# 2  Table 4  2018        3           30325           33728  Denver, CO
# 3  Table 4  2018        3           30325           34321  Denver, CO
# 4  Table 4  2018        3           30325           35096  Denver, CO
#
#              city2  cur_passengers  cur_fare  ly_fare  ly_passengers  \
# 0  Kansas City, MO           27120    189.79   261.58          17760
# 1   Louisville, KY           27870    178.97   233.31          19790
# 2    Pensacola, FL           22740    177.91   257.98          11310
# 3     Portland, ME           24830    213.73   287.89          13810
# 4     Syracuse, NY           19300    231.15   322.04          10980
#
#    amount_change  percent_change  amount_change_pax  percent_change_pax  \
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
fare_highest_lowest_df = pd.read_csv("../Resources/Detailed_Fare_Information_For_Highest_and_Lowest_Fare_Markets_Under_750_Miles.csv")

# Display sample data
fare_highest_lowest_df.head()
# Out:
#        tbl  Year  quarter  mkt_fare  citymarketid_1  citymarketid_2  \
# 0  Table 5  2018        3    130.92           30325           32211
# 1  Table 5  2018        3    130.92           30325           32211
# 2  Table 5  2018        3    139.47           30325           33316
# 3  Table 5  2018        3    139.47           30325           33316
# 4  Table 5  2018        3    271.45           30397           31057
#
#                              city1          city2  carairlineid car  ...  \
# 0                       Denver, CO  Las Vegas, NV         19393  WN  ...
# 1                       Denver, CO  Las Vegas, NV         19977  UA  ...
# 2                       Denver, CO      Omaha, NE         19393  WN  ...
# 3                       Denver, CO      Omaha, NE         19977  UA  ...
# 4  Atlanta, GA (Metropolitan Area)  Charlotte, NC         19790  DL  ...
#
#    carpaxshare  caravgfare  fareinc_min  fareinc_minpaxsh  fareinc_max  \
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
multi_city_df = pd.read_csv("../Resources/Multi_City_Airport_Markets.csv")

# Display sample data
multi_city_df.head()
# Out:
#        tbl  Year  quarter  citymarketid_1  citymarketid_2       city1  \
# 0  Table1a  2018        4           30257           30852  Albany, NY
# 1  Table1a  2018        4           30257           32575  Albany, NY
# 2  Table1a  2018        4           30257           33195  Albany, NY
# 3  Table1a  2018        4           30257           30852  Albany, NY
# 4  Table1a  2018        4           30257           32467  Albany, NY
#
#                                  city2  airportid_1  airportid_2 airport_1  \
# 0   Washington, DC (Metropolitan Area)        10257        11278       ALB
# 1  Los Angeles, CA (Metropolitan Area)        10257        14908       ALB
# 2        Tampa, FL (Metropolitan Area)        10257        14112       ALB
# 3   Washington, DC (Metropolitan Area)        10257        12264       ALB
# 4        Miami, FL (Metropolitan Area)        10257        11697       ALB
#
#    ...    fare  carrier_lg  large_ms  fare_lg carrier_low   lf_ms  fare_low  \
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
state_city_df = pd.read_csv("../Resources/State_City-Pair_Markets.csv")

# Display sample data
state_city_df.head()
# Out:
#    Year  quarter  citymarketid_1  citymarketid_2               city1  \
# 0  2017        1           31057           34614       Charlotte, NC
# 1  2017        1           30666           30466      Bellingham, WA
# 2  2017        1           34614           30559  Salt Lake City, UT
# 3  2017        2           33244           31703         Memphis, TN
# 4  2017        3           33198           31123     Kansas City, MO
#
#                                    city2  nsmiles  passengers    fare  \
# 0                     Salt Lake City, UT     1727         257  266.93
# 1                            Phoenix, AZ     1208         173  124.68
# 2                            Seattle, WA      689         950  192.68
# 3  New York City, NY (Metropolitan Area)     1002         598  293.36
# 4                          St. Louis, MO      237         202  155.21
#
#   carrier_lg  large_ms  fare_lg carrier_low   lf_ms  fare_low  table_1_flag  \
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_average_10_passengers_df = pd.read_csv("../Resources/Table 6 - City_Pair_Markets_Average_10_Passengers_Per_Day.csv")

# Display sample data
city_average_10_passengers_df.head()
# Out:
#        tbl  Year  quarter  citymarketid_1  citymarketid_2          city1  \
# 0  Table 6  2018        4           35550           30852   Valdosta, GA
# 1  Table 6  2018        4           35412           35096  Knoxville, TN
# 2  Table 6  2018        4           35412           34761  Knoxville, TN
# 3  Table 6  2018        4           35412           34685  Knoxville, TN
# 4  Table 6  2018        4           35412           34653  Knoxville, TN
#
#                                 city2  nsmiles  passengers    fare carrier_lg  \
# 0  Washington, DC (Metropolitan Area)      689          12  345.46         DL
# 1                        Syracuse, NY      656          15  270.15         AA
# 2                         Sanford, FL      511         245   88.28         G4
# 3                        Savannah, GA      300          11  244.79         DL
# 4                           Tulsa, OK      666          14  317.66         DL
#
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
fare_passenger_per_day_df = pd.read_csv("../Resources/Table 7 - Fare_Premiums_Select_Cities_with_20_Passengers_Per_Day.csv")

# Display sample data
fare_passenger_per_day_df.head()
# Out:
#        tbl  Year  quarter  citymarketid                        cityname  \
# 0  Table 7  2018        4         34057                    Portland, OR
# 1  Table 7  2018        2         30154                   Nantucket, MA
# 2  Table 7  2018        3         34252    Pasco/Kennewick/Richland, WA
# 3  Table 7  2018        3         34794                  St. George, UT
# 4  Table 7  2018        4         30135  Allentown/Bethlehem/Easton, PA
#
#    airportid  apt  TotalMkts  TotalFaredPax  TotalPerLFMkts  ...     SHPax  \
# 0      14057  PDX        119        3207660          0.7607  ...  878020.0
# 1      10154  ACK          7          19210          1.0000  ...   19210.0
# 2      14252  PSC         36         117760          0.2936  ...   45650.0
# 3      14794  SGU          8          22020          0.0000  ...   22020.0
# 4      10135  ABE         25         115170          0.5192  ...   37170.0
#
#    SHPerLFMkts  SHAvgHubFare  SHPerPrem  LHMkts      LHPax  LHPerLFMkts  \
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_pair_market_summary_df = pd.read_csv("../Resources/Table_2-City_Pair_Markets_Summary_By_City.csv")

# Display sample data
city_pair_market_summary_df.head()
# Out:
#        tbl  Year  quarter  citymarketid                city  markets  \
# 0  Table 2  2018        4         35412       Knoxville, TN        6
# 1  Table 2  2018        4         35096        Syracuse, NY        7
# 2  Table 2  2018        4         34685        Savannah, GA        4
# 3  Table 2  2018        4         34653           Tulsa, OK       11
# 4  Table 2  2018        4         34614  Salt Lake City, UT       32
#
#    cur_passengers  cur_fare  cur_yield  distance  ly_passengers  ly_fare  \
# 0          160310    185.02      31.28     591.6         140460   176.49
# 1          188720    195.20      26.05     749.2         182170   198.37
# 2          192840    184.65      24.85     743.1         179110   188.61
# 3          311680    217.61      26.26     828.8         307590   211.03
# 4         2272030    212.71      20.56    1034.6        2193920   200.75
#
#    ly_yield  ly_distance Geocoded_City      tbl2pk
# 0     29.32        601.9           NaN  2018435412
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_increase_ave_fare_df = pd.read_csv("../Resources/Table_3 - City_Pair Markets_Increase_Average_Fare.csv")

# Display sample data
city_increase_ave_fare_df.head()
# Out:
#        tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 0  Table 3  2018        3           30977           34570
# 1  Table 3  2018        3           30977           34614
# 2  Table 3  2018        3           31057           30647
# 3  Table 3  2018        3           31066           30325
# 4  Table 3  2018        3           30397           30647
#
#                              city1                              city2  \
# 0                      Chicago, IL                           Reno, NV
# 1                      Chicago, IL                 Salt Lake City, UT
# 2                    Charlotte, NC  Cleveland, OH (Metropolitan Area)
# 3                     Columbus, OH                         Denver, CO
# 4  Atlanta, GA (Metropolitan Area)  Cleveland, OH (Metropolitan Area)
#
#    cur_passengers  cur_fare  ly_fare  ly_passengers  amount_change  \
# 0           28730    298.24   252.32          31140          45.92
# ...
