# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import linregress
from scipy import stats
import scipy.stats as st
import seaborn as sns
import requests
from pathlib import Path

# %%
#Reading in data from Table 1a 

multi_city_df = pd.read_csv("../Resources/Multi_City_Airport_Markets.csv")

multi_city_df.head()
# Out:
#        tbl  Year  quarter  citymarketid_1  citymarketid_2       city1  \
# 0  Table1a  2018        4           30257           30852  Albany, NY
# 1  Table1a  2018        4           30257           32575  Albany, NY
# 2  Table1a  2018        4           30257           33195  Albany, NY
# 3  Table1a  2018        4           30257           30852  Albany, NY
# 4  Table1a  2018        4           30257           32467  Albany, NY
#
#                                  city2  airportid_1  airportid_2 airport_1  \
# 0   Washington, DC (Metropolitan Area)        10257        11278       ALB
# 1  Los Angeles, CA (Metropolitan Area)        10257        14908       ALB
# 2        Tampa, FL (Metropolitan Area)        10257        14112       ALB
# 3   Washington, DC (Metropolitan Area)        10257        12264       ALB
# 4        Miami, FL (Metropolitan Area)        10257        11697       ALB
#
#    ...    fare  carrier_lg  large_ms  fare_lg carrier_low   lf_ms  fare_low  \
# 0  ...  190.81          AA    0.9775   190.74          AA  0.9775    190.74
# 1  ...  363.14          UA    0.4599   331.00          UA  0.4599    331.00
# 2  ...  100.78          G4    1.0000   100.78          G4  1.0000    100.78
# 3  ...  184.86          UA    0.9854   184.48          UA  0.9854    184.48
# 4  ...  188.20          B6    0.6067   185.63          B6  0.6067    185.63
#
#   Geocoded_City1  Geocoded_City2                tbl1apk
# 0            NaN             NaN  201841025711278ALBDCA
# 1            NaN             NaN  201841025714908ALBSNA
# 2            NaN             NaN  201841025714112ALBPIE
# 3            NaN             NaN  201841025712264ALBIAD
# 4            NaN             NaN  201841025711697ALBFLL
#
# [5 rows x 23 columns]

# %%
# Create a new DataFrame with updated column names
new_df = multi_city_df.rename(columns={
    'citymarketid_1': 'citymarketid_Dept',
    'citymarketid_2': 'citymarketid_Arriv',
    'city1': 'Departure_city',
    'city2': 'Arrival_city',
    'airportid_1': 'Airportid_Departure',
    'airportid_2': 'Airportid_Arrival',
    'airport_1': 'D_airport_code',
    'airport_2': 'A_airport_code',
    'Geocoded_City1': 'Geocoded_Departure',
    'Geocoded_City2': 'Geocoded_Arrival',
    'nsmiles': 'Non_stop_Miles'
})
# Display the updated DataFrame
new_df.tail()
# Out:
#             tbl  Year  quarter  citymarketid_Dept  citymarketid_Arriv  \
# 16422  Table 1a  2017        1              30436               30852
# 16423  Table 1a  2017        1              30436               30852
# 16424  Table 1a  2017        1              30852               34027
# 16425  Table 1a  2017        1              30852               34027
# 16426  Table 1a  2017        1              30852               34027
#
#                            Departure_city                        Arrival_city  \
# 16422                          Tucson, AZ  Washington, DC (Metropolitan Area)
# 16423                          Tucson, AZ  Washington, DC (Metropolitan Area)
# 16424  Washington, DC (Metropolitan Area)      West Palm Beach/Palm Beach, FL
# 16425  Washington, DC (Metropolitan Area)      West Palm Beach/Palm Beach, FL
# 16426  Washington, DC (Metropolitan Area)      West Palm Beach/Palm Beach, FL
#
#        Airportid_Departure  Airportid_Arrival D_airport_code  ...    fare  \
# 16422                15376              10821            TUS  ...  300.72
# 16423                15376              12264            TUS  ...  359.82
# 16424                10821              14027            BWI  ...  182.51
# 16425                11278              14027            DCA  ...  188.65
# 16426                12264              14027            IAD  ...  212.61
#
#        carrier_lg  large_ms  fare_lg carrier_low   lf_ms  fare_low  \
# 16422          AA    0.4260   328.88          WN  0.3484    260.33
# 16423          UA    0.4197   380.45          WN  0.1466    291.10
# 16424          WN    0.9177   178.75          WN  0.9177    178.75
# 16425          AA    0.6508   201.20          B6  0.2887    151.23
# 16426          DL    0.4496   230.66          WN  0.1425    155.98
#
#                                       Geocoded_Departure  \
# 16422               Tucson, AZ\n(35.167852, -103.726151)
# 16423               Tucson, AZ\n(35.167852, -103.726151)
# 16424  Washington, DC (Metropolitan Area)\n(38.892062...
# 16425  Washington, DC (Metropolitan Area)\n(38.892062...
# 16426  Washington, DC (Metropolitan Area)\n(38.892062...
#
#                                         Geocoded_Arrival  \
# 16422  Washington, DC (Metropolitan Area)\n(38.892062...
# 16423  Washington, DC (Metropolitan Area)\n(38.892062...
# 16424  West Palm Beach/Palm Beach, FL\n(33.90976, -98...
# 16425  West Palm Beach/Palm Beach, FL\n(33.90976, -98...
# 16426  West Palm Beach/Palm Beach, FL\n(33.90976, -98...
#
#                      tbl1apk
# 16422  201711537610821TUSBWI
# 16423  201711537612264TUSIAD
# 16424  201711082114027BWIPBI
# 16425  201711127814027DCAPBI
# 16426  201711226414027IADPBI
#
# [5 rows x 23 columns]

# %%
a = new_df.loc[new_df["Arrival_city"] == "Tampa, FL (Metropolitan Area)", :].fillna({'Geocoded_Arrival':'Tampa, FL (Metropolitan Area)\n(37.8606, -78.804199)'})
b = new_df.loc[new_df["Arrival_city"] == "Seattle, WA", :].fillna({'Geocoded_Arrival':'Seattle, WA\n(47.603229, -122.33028)'})
c = new_df.loc[new_df["Arrival_city"] == "Washington, DC (Metropolitan Area)", :].fillna({'Geocoded_Arrival':'Washington, DC (Metropolitan Area)\n(38.892062, -77.019912)'})
d = new_df.loc[new_df["Departure_city"] == "Los Angeles, CA (Metropolitan Area)", :].fillna({'Geocoded_Departure':'Los Angeles, CA (Metropolitan Area)\n(34.052238, -118.243344)'})

new_df.loc[new_df["Arrival_city"] == "Tampa, FL (Metropolitan Area)"] = a
new_df.loc[new_df["Arrival_city"] == "Seattle , WA"] = b
new_df.loc[new_df["Arrival_city"] == "Washington, DC (Metropolitan Area)"] = c
new_df.loc[new_df["Departure_city"] == "Los Angeles, CA (Metropolitan Area)"] = d


new_df.head()
# Out:
#        tbl  Year  quarter  citymarketid_Dept  citymarketid_Arriv  \
# 0  Table1a  2018        4              30257               30852
# 1  Table1a  2018        4              30257               32575
# 2  Table1a  2018        4              30257               33195
# 3  Table1a  2018        4              30257               30852
# 4  Table1a  2018        4              30257               32467
#
#   Departure_city                         Arrival_city  Airportid_Departure  \
# 0     Albany, NY   Washington, DC (Metropolitan Area)                10257
# 1     Albany, NY  Los Angeles, CA (Metropolitan Area)                10257
# 2     Albany, NY        Tampa, FL (Metropolitan Area)                10257
# 3     Albany, NY   Washington, DC (Metropolitan Area)                10257
# 4     Albany, NY        Miami, FL (Metropolitan Area)                10257
#
#    Airportid_Arrival D_airport_code  ...    fare  carrier_lg  large_ms  \
# 0              11278            ALB  ...  190.81          AA    0.9775
# 1              14908            ALB  ...  363.14          UA    0.4599
# 2              14112            ALB  ...  100.78          G4    1.0000
# 3              12264            ALB  ...  184.86          UA    0.9854
# 4              11697            ALB  ...  188.20          B6    0.6067
#
#    fare_lg carrier_low   lf_ms  fare_low Geocoded_Departure  \
# 0   190.74          AA  0.9775    190.74                NaN
# 1   331.00          UA  0.4599    331.00                NaN
# 2   100.78          G4  1.0000    100.78                NaN
# 3   184.48          UA  0.9854    184.48                NaN
# 4   185.63          B6  0.6067    185.63                NaN
#
#                                     Geocoded_Arrival                tbl1apk
# 0  Washington, DC (Metropolitan Area)\n(38.892062...  201841025711278ALBDCA
# 1                                                NaN  201841025714908ALBSNA
# 2  Tampa, FL (Metropolitan Area)\n(37.8606, -78.8...  201841025714112ALBPIE
# 3  Washington, DC (Metropolitan Area)\n(38.892062...  201841025712264ALBIAD
# 4                                                NaN  201841025711697ALBFLL
#
# [5 rows x 23 columns]

# %%
clean_df = new_df[(new_df['Departure_city'] == 'Los Angeles, CA (Metropolitan Area)') &
                 (new_df['Arrival_city'].isin(['Seattle, WA', 'Washington, DC (Metropolitan Area)', 'Tampa, FL (Metropolitan Area)']))]
clean_df
# Out:
#             tbl  Year  quarter  citymarketid_Dept  citymarketid_Arriv  \
# 1285    Table1a  2018        4              32575               33195
# 1292    Table1a  2018        4              32575               30559
# 1319    Table1a  2018        4              32575               30852
# 1324    Table1a  2018        4              32575               30852
# 1325    Table1a  2018        4              32575               30852
# ...         ...   ...      ...                ...                 ...
# 15847  Table 1a  2017        1              32575               30852
# 15848  Table 1a  2017        1              32575               30852
# 15853  Table 1a  2017        1              32575               30852
# 15881  Table 1a  2017        1              32575               30559
# 15889  Table 1a  2017        1              32575               33195
#
#                             Departure_city  \
# 1285   Los Angeles, CA (Metropolitan Area)
# 1292   Los Angeles, CA (Metropolitan Area)
# 1319   Los Angeles, CA (Metropolitan Area)
# 1324   Los Angeles, CA (Metropolitan Area)
# 1325   Los Angeles, CA (Metropolitan Area)
# ...                                    ...
# 15847  Los Angeles, CA (Metropolitan Area)
# 15848  Los Angeles, CA (Metropolitan Area)
# 15853  Los Angeles, CA (Metropolitan Area)
# 15881  Los Angeles, CA (Metropolitan Area)
# 15889  Los Angeles, CA (Metropolitan Area)
#
#                              Arrival_city  Airportid_Departure  \
# 1285        Tampa, FL (Metropolitan Area)                12892
# 1292                          Seattle, WA                12892
# 1319   Washington, DC (Metropolitan Area)                12892
# 1324   Washington, DC (Metropolitan Area)                12892
# 1325   Washington, DC (Metropolitan Area)                12892
# ...                                   ...                  ...
# 15847  Washington, DC (Metropolitan Area)                14908
# 15848  Washington, DC (Metropolitan Area)                14908
# 15853  Washington, DC (Metropolitan Area)                14908
# 15881                         Seattle, WA                14908
# 15889       Tampa, FL (Metropolitan Area)                14908
#
#        Airportid_Arrival D_airport_code  ...    fare  carrier_lg  large_ms  \
# 1285               15304            LAX  ...  296.07          DL    0.3715
# 1292               14747            LAX  ...  177.68          AS    0.5631
# 1319               12264            LAX  ...  310.32          UA    0.5517
# 1324               11278            LAX  ...  305.38          AA    0.4535
# 1325               10821            LAX  ...  221.51          WN    0.4442
# ...                  ...            ...  ...     ...         ...       ...
# 15847              10821            SNA  ...  293.13          WN    0.4824
# 15848              11278            SNA  ...  341.93          AA    0.3481
# 15853              12264            SNA  ...  371.96          UA    0.5643
# 15881              14747            SNA  ...  156.86          AS    0.7098
# 15889              15304            SNA  ...  330.67          AA    0.3525
#
#        fare_lg carrier_low   lf_ms  fare_low  \
# 1285    368.40          WN  0.3380    241.02
# 1292    169.76          AS  0.5631    169.76
# 1319    357.82          AS  0.2095    226.80
# 1324    321.18          AS  0.2020    260.36
# 1325    242.89          NK  0.1541    123.65
# ...        ...         ...     ...       ...
# 15847   279.07          UA  0.1887    261.29
# 15848   399.35          F9  0.1069    160.55
# 15853   389.77          AA  0.2151    365.07
# 15881   157.14          AS  0.7098    157.14
# 15889   359.05          WN  0.2376    311.30
#
#                                       Geocoded_Departure  \
# 1285   Los Angeles, CA (Metropolitan Area)\n(34.05223...
# 1292   Los Angeles, CA (Metropolitan Area)\n(34.05223...
# 1319   Los Angeles, CA (Metropolitan Area)\n(34.05223...
# 1324   Los Angeles, CA (Metropolitan Area)\n(34.05223...
# 1325   Los Angeles, CA (Metropolitan Area)\n(34.05223...
# ...                                                  ...
# 15847  Los Angeles, CA (Metropolitan Area)\n(34.05223...
# 15848  Los Angeles, CA (Metropolitan Area)\n(34.05223...
# 15853  Los Angeles, CA (Metropolitan Area)\n(34.05223...
# 15881  Los Angeles, CA (Metropolitan Area)\n(34.05223...
# 15889  Los Angeles, CA (Metropolitan Area)\n(34.05223...
#
#                                         Geocoded_Arrival  \
# 1285                                                 NaN
# 1292                                                 NaN
# 1319                                                 NaN
# 1324                                                 NaN
# 1325                                                 NaN
# ...                                                  ...
# 15847  Washington, DC (Metropolitan Area)\n(38.892062...
# 15848  Washington, DC (Metropolitan Area)\n(38.892062...
# 15853  Washington, DC (Metropolitan Area)\n(38.892062...
# 15881               Seattle, WA\n(47.603229, -122.33028)
# 15889  Tampa, FL (Metropolitan Area)\n(37.8606, -78.8...
#
#                      tbl1apk
# 1285   201841289215304LAXTPA
# 1292   201841289214747LAXSEA
# 1319   201841289212264LAXIAD
# 1324   201841289211278LAXDCA
# 1325   201841289210821LAXBWI
# ...                      ...
# 15847  201711490810821SNABWI
# 15848  201711490811278SNADCA
# 15853  201711490812264SNAIAD
# 15881  201711490814747SNASEA
# 15889  201711490815304SNATPA
#
# [200 rows x 23 columns]

# %%
# Export the cleaned dataframe to the Resources folder as a CSV, without the Pandas index, but with the header
clean_df.to_csv("../Resources/Clean_Multi_City_Airport_Markets.csv", index=False, header=True)

# %%
#Reading in Table 2 into a csv 
state_city_df = pd.read_csv("../Resources/State_City-Pair_Markets.csv")
state_city_df.head()
# Out:
#    Year  quarter  citymarketid_1  citymarketid_2               city1  \
# 0  2017        1           31057           34614       Charlotte, NC
# 1  2017        1           30666           30466      Bellingham, WA
# 2  2017        1           34614           30559  Salt Lake City, UT
# 3  2017        2           33244           31703         Memphis, TN
# 4  2017        3           33198           31123     Kansas City, MO
#
#                                    city2  nsmiles  passengers    fare  \
# 0                     Salt Lake City, UT     1727         257  266.93
# 1                            Phoenix, AZ     1208         173  124.68
# 2                            Seattle, WA      689         950  192.68
# 3  New York City, NY (Metropolitan Area)     1002         598  293.36
# 4                          St. Louis, MO      237         202  155.21
#
#   carrier_lg  large_ms  fare_lg carrier_low   lf_ms  fare_low  table_1_flag  \
# 0         DL    0.4743   276.41          AA  0.4163    264.35             1
# 1         G4    0.7641   108.19          G4  0.7641    108.19             1
# 2         DL    0.4988   205.89          AS  0.4483    180.66             1
# 3         AA    0.3623   273.59          AA  0.3623    273.59             1
# 4         WN    1.0000   155.21          WN  1.0000    155.21             1
#
#                                  Geocoded_City1  \
# 0        Charlotte, NC\n(35.222936, -80.840161)
# 1       Bellingham, WA\n(41.698264, -88.077915)
# 2  Salt Lake City, UT\n(40.758478, -111.888142)
# 3          Memphis, TN\n(35.143378, -90.052136)
# 4      Kansas City, MO\n(39.099792, -94.578559)
#
#                                       Geocoded_City2
# 0       Salt Lake City, UT\n(40.758478, -111.888142)
# 1               Phoenix, AZ\n(30.406931, -87.217578)
# 2               Seattle, WA\n(47.603229, -122.33028)
# 3  New York City, NY (Metropolitan Area)\n(40.123...
# 4             St. Louis, MO\n(38.630276, -90.200309)
